# %%
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import categorical_accuracy

size_ = 64

model = Sequential()

model.add(Conv2D(128, (5, 5), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(128, (5, 5), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(256, (5, 5), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(256, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Flatten())
model.add(Dense(units = 4, activation = 'softmax'))
model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = [categorical_accuracy])
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 60, 60, 128)       9728
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       409728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 256)         819456
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 1,830,020
# Trainable params: 1,830,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
train = ImageDataGenerator(rescale = 1./255)
test = ImageDataGenerator(rescale = 1./255)
train_data = train.flow_from_directory('rice-leaf/training', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
test_data = test.flow_from_directory('rice-leaf/testing', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-72bf81b162cc> in <module>
#       1 train = ImageDataGenerator(rescale = 1./255)
#       2 test = ImageDataGenerator(rescale = 1./255)
# ----> 3 train_data = train.flow_from_directory('rice-leaf/training', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
#       4 test_data = test.flow_from_directory('rice-leaf/testing', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
#
# D:\ANACONDA\envs\tensorflow\lib\site-packages\keras\preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     465             follow_links=follow_links,
#     466             subset=subset,
# --> 467             interpolation=interpolation
#     468         )
#     469
#
# D:\ANACONDA\envs\tensorflow\lib\site-packages\keras\preprocessing\image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     148             subset=subset,
#     149             interpolation=interpolation,
# --> 150             dtype=dtype)
#     151
#     152
#
# D:\ANACONDA\envs\tensorflow\lib\site-packages\keras_preprocessing\image\directory_iterator.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     104         if not classes:
#     105             classes = []
# --> 106             for subdir in sorted(os.listdir(directory)):
#     107                 if os.path.isdir(os.path.join(directory, subdir)):
#     108                     classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'rice-leaf/training'

# %%
history=model.fit_generator(train_data, steps_per_epoch = 100, epochs = 50, validation_data = test_data, validation_steps = 100)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 110s 1s/step - loss: 1.2284 - categorical_accuracy: 0.4553 - val_loss: 0.9094 - val_categorical_accuracy: 0.5634
# Epoch 2/50
# 100/100 [==============================] - 107s 1s/step - loss: 0.9141 - categorical_accuracy: 0.5747 - val_loss: 0.8409 - val_categorical_accuracy: 0.5966
# Epoch 3/50
# 100/100 [==============================] - 109s 1s/step - loss: 0.8284 - categorical_accuracy: 0.6084 - val_loss: 0.8760 - val_categorical_accuracy: 0.6269
# Epoch 4/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.7612 - categorical_accuracy: 0.6625 - val_loss: 0.7686 - val_categorical_accuracy: 0.6403
# Epoch 5/50
# 100/100 [==============================] - 111s 1s/step - loss: 0.7285 - categorical_accuracy: 0.6853 - val_loss: 0.6605 - val_categorical_accuracy: 0.6534
# Epoch 6/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.6564 - categorical_accuracy: 0.7188 - val_loss: 0.5857 - val_categorical_accuracy: 0.7091
# Epoch 7/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.6573 - categorical_accuracy: 0.7228 - val_loss: 0.6416 - val_categorical_accuracy: 0.7103
# Epoch 8/50
# 100/100 [==============================] - 107s 1s/step - loss: 0.6215 - categorical_accuracy: 0.7375 - val_loss: 0.6563 - val_categorical_accuracy: 0.7050
# Epoch 9/50
# 100/100 [==============================] - 105s 1s/step - loss: 0.5829 - categorical_accuracy: 0.7513 - val_loss: 0.5897 - val_categorical_accuracy: 0.6484
# Epoch 10/50
# 100/100 [==============================] - 109s 1s/step - loss: 0.5424 - categorical_accuracy: 0.7775 - val_loss: 0.4776 - val_categorical_accuracy: 0.6991
# Epoch 11/50
# 100/100 [==============================] - 111s 1s/step - loss: 0.5173 - categorical_accuracy: 0.7859 - val_loss: 0.6916 - val_categorical_accuracy: 0.7181
# Epoch 12/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.4891 - categorical_accuracy: 0.7981 - val_loss: 0.8045 - val_categorical_accuracy: 0.6388
# Epoch 13/50
# 100/100 [==============================] - 111s 1s/step - loss: 0.4473 - categorical_accuracy: 0.8191 - val_loss: 0.8520 - val_categorical_accuracy: 0.7600
# Epoch 14/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.4711 - categorical_accuracy: 0.8081 - val_loss: 0.4174 - val_categorical_accuracy: 0.6903
# Epoch 15/50
# 100/100 [==============================] - 110s 1s/step - loss: 0.3993 - categorical_accuracy: 0.8419 - val_loss: 0.5554 - val_categorical_accuracy: 0.6950
# Epoch 16/50
# 100/100 [==============================] - 101s 1s/step - loss: 0.4120 - categorical_accuracy: 0.8384 - val_loss: 0.6691 - val_categorical_accuracy: 0.7731
# Epoch 17/50
# 100/100 [==============================] - 101s 1s/step - loss: 0.3516 - categorical_accuracy: 0.8653 - val_loss: 0.6875 - val_categorical_accuracy: 0.7931
# Epoch 18/50
# 100/100 [==============================] - 99s 993ms/step - loss: 0.3607 - categorical_accuracy: 0.8619 - val_loss: 0.6572 - val_categorical_accuracy: 0.6747
# Epoch 19/50
# 100/100 [==============================] - 99s 990ms/step - loss: 0.3485 - categorical_accuracy: 0.8606 - val_loss: 0.5787 - val_categorical_accuracy: 0.6888
# Epoch 20/50
# 100/100 [==============================] - 100s 1s/step - loss: 0.2870 - categorical_accuracy: 0.8891 - val_loss: 0.7954 - val_categorical_accuracy: 0.7381
# Epoch 21/50
# 100/100 [==============================] - 100s 999ms/step - loss: 0.3043 - categorical_accuracy: 0.8822 - val_loss: 0.7681 - val_categorical_accuracy: 0.7794
# Epoch 22/50
# 100/100 [==============================] - 101s 1s/step - loss: 0.2848 - categorical_accuracy: 0.8869 - val_loss: 0.7101 - val_categorical_accuracy: 0.6031
# Epoch 23/50
# 100/100 [==============================] - 104s 1s/step - loss: 0.4095 - categorical_accuracy: 0.8525 - val_loss: 0.2656 - val_categorical_accuracy: 0.8019
# Epoch 24/50
# 100/100 [==============================] - 104s 1s/step - loss: 0.2298 - categorical_accuracy: 0.9169 - val_loss: 0.5632 - val_categorical_accuracy: 0.7531
# Epoch 25/50
# 100/100 [==============================] - 104s 1s/step - loss: 0.2689 - categorical_accuracy: 0.9069 - val_loss: 0.6325 - val_categorical_accuracy: 0.7459
# Epoch 26/50
# 100/100 [==============================] - 86s 860ms/step - loss: 0.2075 - categorical_accuracy: 0.9231 - val_loss: 0.3777 - val_categorical_accuracy: 0.7616
# Epoch 27/50
# 100/100 [==============================] - 87s 870ms/step - loss: 0.2089 - categorical_accuracy: 0.9247 - val_loss: 0.3512 - val_categorical_accuracy: 0.7450
# Epoch 28/50
# 100/100 [==============================] - 88s 880ms/step - loss: 0.1698 - categorical_accuracy: 0.9394 - val_loss: 0.3577 - val_categorical_accuracy: 0.8209
# Epoch 29/50
# 100/100 [==============================] - 89s 886ms/step - loss: 0.1622 - categorical_accuracy: 0.9391 - val_loss: 0.4902 - val_categorical_accuracy: 0.7822
# Epoch 30/50
# 100/100 [==============================] - 87s 869ms/step - loss: 0.1681 - categorical_accuracy: 0.9453 - val_loss: 0.3012 - val_categorical_accuracy: 0.7875
# Epoch 31/50
# 100/100 [==============================] - 87s 869ms/step - loss: 0.2050 - categorical_accuracy: 0.9262 - val_loss: 0.6587 - val_categorical_accuracy: 0.7825
# Epoch 32/50
# 100/100 [==============================] - 87s 874ms/step - loss: 0.1435 - categorical_accuracy: 0.9513 - val_loss: 0.2075 - val_categorical_accuracy: 0.8466
# Epoch 33/50
# 100/100 [==============================] - 88s 880ms/step - loss: 0.1003 - categorical_accuracy: 0.9706 - val_loss: 0.4888 - val_categorical_accuracy: 0.8234
# Epoch 34/50
# 100/100 [==============================] - 88s 881ms/step - loss: 0.1469 - categorical_accuracy: 0.9488 - val_loss: 0.7663 - val_categorical_accuracy: 0.8350
# Epoch 35/50
# 100/100 [==============================] - 84s 840ms/step - loss: 0.1133 - categorical_accuracy: 0.9600 - val_loss: 0.6494 - val_categorical_accuracy: 0.8116
# Epoch 36/50
# 100/100 [==============================] - 84s 840ms/step - loss: 0.0931 - categorical_accuracy: 0.9675 - val_loss: 0.6986 - val_categorical_accuracy: 0.8116
# Epoch 37/50
# 100/100 [==============================] - 84s 842ms/step - loss: 0.1040 - categorical_accuracy: 0.9600 - val_loss: 0.2347 - val_categorical_accuracy: 0.8300
# Epoch 38/50
# 100/100 [==============================] - 86s 864ms/step - loss: 0.0758 - categorical_accuracy: 0.9756 - val_loss: 0.3030 - val_categorical_accuracy: 0.8175
# Epoch 39/50
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1204 - categorical_accuracy: 0.9609 - val_loss: 0.3922 - val_categorical_accuracy: 0.8444
# Epoch 40/50
# 100/100 [==============================] - 80s 801ms/step - loss: 0.0683 - categorical_accuracy: 0.9781 - val_loss: 0.5293 - val_categorical_accuracy: 0.8522
# Epoch 41/50
# 100/100 [==============================] - 80s 798ms/step - loss: 0.0549 - categorical_accuracy: 0.9837 - val_loss: 0.5743 - val_categorical_accuracy: 0.8228
# Epoch 42/50
# 100/100 [==============================] - 80s 796ms/step - loss: 0.0554 - categorical_accuracy: 0.9819 - val_loss: 0.4526 - val_categorical_accuracy: 0.8434
# Epoch 43/50
# 100/100 [==============================] - 80s 801ms/step - loss: 0.1515 - categorical_accuracy: 0.9538 - val_loss: 0.1895 - val_categorical_accuracy: 0.7944
# Epoch 44/50
# 100/100 [==============================] - 80s 796ms/step - loss: 0.0824 - categorical_accuracy: 0.9709 - val_loss: 0.3838 - val_categorical_accuracy: 0.8300
# Epoch 45/50
# 100/100 [==============================] - 80s 798ms/step - loss: 0.1392 - categorical_accuracy: 0.9584 - val_loss: 0.4644 - val_categorical_accuracy: 0.8288
# Epoch 46/50
# 100/100 [==============================] - 87s 873ms/step - loss: 0.0667 - categorical_accuracy: 0.9778 - val_loss: 0.3028 - val_categorical_accuracy: 0.8369
# Epoch 47/50
# 100/100 [==============================] - 91s 910ms/step - loss: 0.0497 - categorical_accuracy: 0.9828 - val_loss: 0.1288 - val_categorical_accuracy: 0.8462
# Epoch 48/50
# 100/100 [==============================] - 88s 876ms/step - loss: 0.0396 - categorical_accuracy: 0.9862 - val_loss: 0.4546 - val_categorical_accuracy: 0.8228
# Epoch 49/50
# 100/100 [==============================] - 88s 880ms/step - loss: 0.0444 - categorical_accuracy: 0.9866 - val_loss: 0.4829 - val_categorical_accuracy: 0.8213
# Epoch 50/50
# 100/100 [==============================] - 88s 877ms/step - loss: 0.0420 - categorical_accuracy: 0.9869 - val_loss: 1.0614 - val_categorical_accuracy: 0.8625

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validasi'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validasi'], loc='upper left')
plt.show()
